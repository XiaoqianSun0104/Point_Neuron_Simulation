# %%
import os 
import signals, neuron, connectivity, simulation, visualization
import importlib;importlib.reload(neuron);importlib.reload(connectivity);importlib.reload(simulation)


import warnings
warnings.filterwarnings('ignore')
print('working in', os.getcwd())
# Out:
# working in /Users/xiaoqiansun/Desktop/AD钙奶/A_WorkStation/Simulation/Simulation/Version1

# %% [markdown]
# # Case 0

# %%
# necessary parameters

T = 100
dt = 0.1
gE_bar = 0.15
gI_bar = 0.30

Ne = 4
Ni = 4
N = Ne+Ni

maxns=1000


# customize any exc/inh attributes and create a list of neuron objects
exc_kwargs = {'externalInput':200}
inh_kwargs = {'tref':0.5, 'tau_m':15}
neuornObj_list = [neuron.Neuron(T, dt, gE_bar, gI_bar, 0, **exc_kwargs) for i in range(Ne)]+\
                [neuron.Neuron(T, dt, gE_bar, gI_bar, 1, **inh_kwargs) for i in range(Ni)]
print(len(neuornObj_list), 'neuron objects in total\n'); print()


# connectivity attributes
cm_kwargs = {'p_exc2exc':0.6, 'p_inh2exc':0.8, 'w_inh2exc':0.35}


# initialize simulator
simulator = simulation.Simulator(T, dt, N, Ne, Ni, maxns, neuornObj_list, **cm_kwargs)


simuResults = []
# set exc externalInput different values and see how that drive the spike generation of the network
for I_b in [180, 200, 220]:
    print('Initial connectivity df with weights:'); print(simulator.CMW_df); print()
    
    print('Set externalInput to', I_b, 'and run' )
    simulator.set({'externalInput':I_b})
    simulator.run()
    simuResults.append(simulator.copy())
    print('The network generate spk:', simulator.get('netSpk'))
    print('Final connectivity df with weights:'); print(simulator.CMW_df); print()
    print('--------------------------------------------------------')
# Out:
# 8 neuron objects in total
#
#
# Initial connectivity df with weights:
#       1E    2E    3E    4E   1I   2I   3I   4I
# 1E  0.00  0.00  0.10  0.00  0.0  0.0  0.0  0.0
# 2E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 3E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 4E  0.00  0.10  0.10  0.00  0.0  0.0  0.0  0.0
# 1I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 2I  0.35  0.35  0.00  0.00  0.0  0.0  0.0  0.0
# 3I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 4I  0.35  0.35  0.00  0.35  0.0  0.0  0.0  0.0
#
# Set externalInput to 180 and run
# The simulation takes 0.01 minutes
# The network generate spk: [[0.]
#  [0.]]
# Final connectivity df with weights:
#       1E    2E    3E    4E   1I   2I   3I   4I
# 1E  0.00  0.00  0.10  0.00  0.0  0.0  0.0  0.0
# 2E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 3E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 4E  0.00  0.10  0.10  0.00  0.0  0.0  0.0  0.0
# 1I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 2I  0.35  0.35  0.00  0.00  0.0  0.0  0.0  0.0
# 3I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 4I  0.35  0.35  0.00  0.35  0.0  0.0  0.0  0.0
#
# --------------------------------------------------------
# Initial connectivity df with weights:
#       1E    2E    3E    4E   1I   2I   3I   4I
# 1E  0.00  0.00  0.10  0.00  0.0  0.0  0.0  0.0
# 2E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 3E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 4E  0.00  0.10  0.10  0.00  0.0  0.0  0.0  0.0
# 1I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 2I  0.35  0.35  0.00  0.00  0.0  0.0  0.0  0.0
# 3I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 4I  0.35  0.35  0.00  0.35  0.0  0.0  0.0  0.0
#
# Set externalInput to 200 and run
# The simulation takes 0.011 minutes
# The network generate spk: [[0.]
#  [0.]]
# Final connectivity df with weights:
#       1E    2E    3E    4E   1I   2I   3I   4I
# 1E  0.00  0.00  0.10  0.00  0.0  0.0  0.0  0.0
# 2E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 3E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 4E  0.00  0.10  0.10  0.00  0.0  0.0  0.0  0.0
# 1I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 2I  0.35  0.35  0.00  0.00  0.0  0.0  0.0  0.0
# 3I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 4I  0.35  0.35  0.00  0.35  0.0  0.0  0.0  0.0
#
# --------------------------------------------------------
# Initial connectivity df with weights:
#       1E    2E    3E    4E   1I   2I   3I   4I
# 1E  0.00  0.00  0.10  0.00  0.0  0.0  0.0  0.0
# 2E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 3E  0.10  0.00  0.00  0.00  0.0  0.0  0.0  0.0
# 4E  0.00  0.10  0.10  0.00  0.0  0.0  0.0  0.0
# 1I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 2I  0.35  0.35  0.00  0.00  0.0  0.0  0.0  0.0
# 3I  0.35  0.00  0.35  0.00  0.0  0.0  0.0  0.0
# 4I  0.35  0.35  0.00  0.35  0.0  0.0  0.0  0.0
#
# Set externalInput to 220 and run
# The simulation takes 0.011 minutes
# The network generate spk: [[32.  32.  32.  32.  43.1 43.5 43.5 44.3 68.4 68.4 68.4 68.4 93.2 93.7
#   93.8 94.9  0. ]
#  [ 4.   5.   6.   7.   3.   1.   2.   0.   4.   5.   6.   7.   3.   2.
#    1.   0.   0. ]]
# Final connectivity df with weights:
#           1E        2E        3E        4E   1I   2I   3I   4I
# 1E  0.000000  0.000000  0.084913  0.000000  0.0  0.0  0.0  0.0
# 2E  0.116782  0.000000  0.000000  0.000000  0.0  0.0  0.0  0.0
# 3E  0.116737  0.000000  0.000000  0.000000  0.0  0.0  0.0  0.0
# 4E  0.000000  0.117195  0.117242  0.000000  0.0  0.0  0.0  0.0
# 1I  0.357462  0.000000  0.357757  0.000000  0.0  0.0  0.0  0.0
# 2I  0.357462  0.357740  0.000000  0.000000  0.0  0.0  0.0  0.0
# 3I  0.357462  0.000000  0.357757  0.000000  0.0  0.0  0.0  0.0
# 4I  0.357462  0.357740  0.000000  0.357896  0.0  0.0  0.0  0.0
#
# --------------------------------------------------------
